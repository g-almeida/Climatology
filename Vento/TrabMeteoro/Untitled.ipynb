# %%
import pandas as pd
import seaborn as sea

# %%
SL = pd.read_csv("D:/_Gabriel/Estudo/UFF/5 Período/Meteorologia/Trabalho-Ventos/Dados/Selected/teste_dados_BELOHORIZONTE_83587_H_2000-01-01_2019-12-31.csv", sep = ";")

# %%
nulos = SL.isnull()

# %%
sea.heatmap(nulos)
# Out:
# <AxesSubplot:>
