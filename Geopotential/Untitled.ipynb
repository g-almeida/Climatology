# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import cartopy
import pandas as pd
import xarray as xr
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import metpy.calc as mpcalc
import json
import calendar
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature 
import matplotlib.font_manager as font_manager
import matplotlib.ticker as mticker
import matplotlib.patches as mpatches
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from mpl_toolkits.axes_grid1 import make_axes_locatable
import seaborn as sns
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
from cartopy.util import add_cyclic_point

# %matplotlib inline
import numpy as np
import pandas as pd
import xarray as xr
from netCDF4 import num2date
import matplotlib.pyplot as plt

# %%
hgtdata = xr.open_dataset('D:/_Gabriel/Estudo/UFF/Bloqueios_Atmosfericos/Climatologias/nc/GP_79_20.nc')
hgtdata

hgt = hgtdata.isel(expver=0)

# %%
hgt14 = hgt.z.where(hgt.z>=14000).where(hgt.z<=14100).drop('expver')
hgt14
# Out:
# <xarray.DataArray 'z' (time: 496, latitude: 161, longitude: 261)>
# array([[[       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         ...,
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan]],
#
#        [[       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
#         [       nan,        nan,        nan, ...,        nan,
#                 nan,        nan],
# ...

# %%
df = hgt14.isnull().to_dataframe()
df.nunique()
# Out:
# z    2
# dtype: int64

# %%
df
# Out:
#                                   z
# time       latitude longitude
# 1979-01-01 -5.0     -50.00     True
#                     -49.75     True
#                     -49.50     True
#                     -49.25     True
#                     -49.00     True
# ...                             ...
# 2020-04-01 -45.0     14.00     True
#                      14.25     True
#                      14.50     True
#                      14.75     True
#                      15.00     True
#
# [20842416 rows x 1 columns]

# %%
df2 = df.where(df['z']==False)
df2
# Out:
#                                 z
# time       latitude longitude
# 1979-01-01 -5.0     -50.00    NaN
#                     -49.75    NaN
#                     -49.50    NaN
#                     -49.25    NaN
#                     -49.00    NaN
# ...                            ..
# 2020-04-01 -45.0     14.00    NaN
#                      14.25    NaN
#                      14.50    NaN
#                      14.75    NaN
#                      15.00    NaN
#
# [20842416 rows x 1 columns]

# %%
df3 = df2.dropna(axis=0)
df3
# Out:
#                                  z
# time       latitude longitude
# 1979-01-01 -43.25   13.25      0.0
#                     13.50      0.0
#                     13.75      0.0
#                     14.00      0.0
#                     14.25      0.0
# ...                            ...
# 2020-03-01 -45.00   14.00      0.0
#                     14.25      0.0
#                     14.50      0.0
#                     14.75      0.0
#                     15.00      0.0
#
# [315104 rows x 1 columns]

# %%
df3.loc['1979-01-01',-43.25]
# Out:
# <ipython-input-67-d9f8db7de2c7>:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   df3.loc['1979-01-01',-43.25]
#            expver    z
# longitude
# 13.25         1.0  0.0
# 13.50         1.0  0.0
# 13.75         1.0  0.0
# 14.00         1.0  0.0
# 14.25         1.0  0.0
# 14.50         1.0  0.0
# 14.75         1.0  0.0
# 15.00         1.0  0.0

# %%
df3.index[0]
# Out:
# (Timestamp('1979-01-01 00:00:00'), -43.25, 13.25)
